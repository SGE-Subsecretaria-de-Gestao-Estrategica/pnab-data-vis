# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config import settings
# from src.aggregations import , person, labor,cadunico
import pandas as pd 
import numpy as np
from pathlib import Path

# import importlib
# importlib.reload(settings)
# importlib.reload(territorial)
# importlib.reload(person)
# importlib.reload(labor)
# importlib.reload(cadunico)

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df_v_range = pd.read_csv(settings.DATA_PATH_SECTION2 / 'values_range_by_brazil.csv')

# %%
df_v_range
# Out:
#    Unnamed: 0         faixa_vlr_pago  Quantidade de contemplados  \
# 0           0              Até 2 mil                       49037
# 1           1             2 a 10 mil                       70493
# 2           2            10 a 50 mil                       37661
# 3           3           50 a 200 mil                        8348
# 4           4          200 a 500 mil                        1099
# 5           5     500 mil a 1 milhão                         160
# 6           6  1 milhão a 10 milhões                          86
# 7           7    Acima de 10 milhões                           2
#
#    % de contemplados
# 0               0.29
# 1               0.42
# 2               0.23
# 3               0.05
# 4               0.01
# 5               0.00
# 6               0.00
# 7               0.00
