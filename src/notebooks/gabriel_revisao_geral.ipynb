# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config import settings
# from src.aggregations import , person, labor,cadunico
import pandas as pd 
import numpy as np
from pathlib import Path

# import importlib
# importlib.reload(settings)
# importlib.reload(territorial)
# importlib.reload(person)
# importlib.reload(labor)
# importlib.reload(cadunico)

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df_big_number = pd.read_csv(settings.DATA_PATH_SECTION1 / 'bignumber1.csv')

# %%
df_executed_by_uf = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_uf.csv')

# %%
df_executed_by_state = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_state.csv')

# %%
df_executed_by_pop_size = pd.read_csv(settings.DATA_PATH_SECTION1 / 'values_by_population_size.csv')

# %%
df_capital = pd.read_csv(settings.DATA_PATH_SECTION1 / 'aggregate_values_by_capital.csv')

# %%
df_zone = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_state.csv')

# %%
df_territorio_especial = pd.read_csv(settings.DATA_PATH_SECTION1 / 'special_territory_w_ibge_by_brazil.csv')

# %%
df_territorio_especial
# Out:
#    Unnamed: 0                  territorio  Valor (R$)  \
# 0           0  Favela e Comunidade Urbana   138146185
# 1           1      Agrupamento quilombola     7369210
# 2           2        Agrupamento indígena     5078944
#
#    Quantidade de contemplados  % recurso total  % de agentes contemplados  \
# 0                        4555             4.85                       0.00
# 1                         481             0.26                       0.00
# 2                         254             0.18                       0.00
#
#    % população no território
# 0                       8.00
# 1                       0.70
# 2                       0.83

# %%
4555/166000
# Out:
# 0.027439759036144578

# %%
df_territorio_especial_pt2 = pd.read_csv(settings.DATA_PATH_SECTION1 / 'values_by_special_territory_uf.csv')

# %%
df_territorio_especial_pt2
# Out:
#     Unnamed: 0                       cod_tipo_nome  valor_transacao  \
# 0            0                        Não especial       2653700009
# 1            1          Favela e Comunidade Urbana        138146185
# 2            2  Setor com baixo patamar domiciliar         21852365
# 3            3              Agrupamento quilombola          7369210
# 4            4                Agrupamento indígena          5078944
# 5            5              Quartel e base militar           480603
# 6            6                       Não informado         18385602
# 7            7                      Agrovila do PA           540519
# 8            8                   Unidade prisional            86969
# 9            9   Convento / hospital / ILPI / IACA           152685
# 10          10            Alojamento / acampamento           202508
#
#     perc_valor_transacao  quantidade_contemplados  \
# 0                   0.93                   160271
# 1                   0.05                     4555
# 2                   0.01                      673
# 3                   0.00                      481
# 4                   0.00                      254
# 5                   0.00                       24
# 6                   0.01                      534
# 7                   0.00                       63
# 8                   0.00                       10
# 9                   0.00                       13
# 10                  0.00                        8
#
#     perc_quantidade_contemplados  qtd_tipo_documento_CNPJ  \
# 0                           0.96                    30918
# 1                           0.03                      864
# 2                           0.00                      260
# 3                           0.00                       72
# 4                           0.00                       22
# 5                           0.00                        1
# 6                           0.00                      135
# 7                           0.00                        4
# 8                           0.00                        1
# 9                           0.00                        3
# 10                          0.00                        0
#
#     qtd_tipo_documento_CPF  valor_tipo_documento_CNPJ  \
# 0                   129353                 1479002422
# 1                     3691                   76558971
# 2                      413                   15226973
# 3                      409                    3509108
# 4                      232                    1391182
# 5                       23                     300000
# 6                      399                   15166170
# 7                       59                      66000
# 8                        9                       6870
# 9                       10                      84000
# 10                       8                          0
#
#     valor_tipo_documento_CPF  min_valor_tipo_documento_CNPJ  \
# 0                 1174697588                            375
# 1                   61587214                            431
# 2                    6625393                            406
# 3                    3860103                           1034
# 4                    3687762                           4000
# 5                     180603                         300000
# 6                    3219433                            380
# 7                     474519                           6000
# 8                      80099                           6870
# 9                      68685                           4000
# 10                    202508                              0
#
#     min_valor_tipo_documento_CPF  mediana_valor_tipo_documento_CNPJ  \
# 0                            375                              12941
# 1                            400                              36000
# 2                            378                              20000
# 3                            500                              29307
# 4                            500                              25883
# 5                           1089                             300000
# 6                            500                              20000
# 7                            500                              20000
# 8                            800                               6870
# 9                           2000                              20000
# 10                          1000                                  0
#
#     mediana_valor_tipo_documento_CPF  max_valor_tipo_documento_CNPJ  \
# 0                               3572                       19987818
# 1                              10000                       22109765
# 2                               5000                        1031144
# 3                               3200                         329600
# 4                               5500                         250000
# 5                               3842                         300000
# 6                               3000                        2017102
# 7                               3334                          20000
# 8                               6000                           6870
# 9                               5705                          60000
# 10                              8500                              0
#
#     max_valor_tipo_documento_CPF  media_valor_tipo_documento_CNPJ  \
# 0                         735000                            61086
# 1                         400000                           109214
# 2                         650000                            59714
# 3                         150000                            52375
# 4                         294095                            63236
# 5                          50000                           300000
# 6                         330000                           156353
# 7                         127223                            16500
# 8                          26880                             6870
# 9                          15000                            28000
# 10                        105000                                0
#
#     media_valor_tipo_documento_CPF
# 0                             9395
# 1                            16874
# 2                            16082
# 3                             9532
# 4                            16175
# 5                             7853
# 6                             8384
# 7                             8043
# 8                             8900
# 9                             6869
# 10                           25314
