# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config import settings
# from src.aggregations import , person, labor,cadunico
import pandas as pd 
import numpy as np
from pathlib import Path

# import importlib
# importlib.reload(settings)
# importlib.reload(territorial)
# importlib.reload(person)
# importlib.reload(labor)
# importlib.reload(cadunico)

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df_big_number = pd.read_csv(settings.DATA_PATH_SECTION1 / 'bignumber1.csv')

# %%
df_executed_by_uf = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_uf.csv')

# %%
df_executed_by_state = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_state.csv')

# %%
df_executed_by_pop_size = pd.read_csv(settings.DATA_PATH_SECTION1 / 'values_by_population_size.csv')

# %%
df_executed_by_pop_size
# Out:
#    Unnamed: 0 porte_populacional  numero_municipios  valor_total_por_porte  \
# 0           0                -99                 27             1450514327
# 1           1           4_grande                332              732942052
# 2           2        1_pequeno_i               3401              266445333
# 3           3       2_pequeno_ii               1030              234896276
# 4           4            3_medio                334              161197609
#
#    valor_urbano_por_porte  valor_rural_por_porte  \
# 0              1364352208               81220798
# 1               706336743               13439537
# 2               226313099               39514921
# 3               204820060               29163319
# 4               147500753               12718074
#
#    quantidade_contemplados_por_porte  quantidade_contemplados_urbano  \
# 0                              22050                           20120
# 1                              31255                           30136
# 2                              57289                           44350
# 3                              38944                           32136
# 4                              17348                           15551
#
#    quantidade_contemplados_rural  1 milhão a 10 milhões  10 a 50 mil  \
# 0                           1843                     69        11454
# 1                            993                     17        13359
# 2                          12753                      0         4511
# 3                           6701                      0         4424
# 4                           1653                      0         3913
#
#    2 a 10 mil  200 a 500 mil  50 a 200 mil  500 mil a 1 milhão  Até 2 mil  \
# 0        4479            896          4924                 137         89
# 1       12986            162          2388                  22       2321
# 2       23629              7           447                   0      28695
# 3       19876             22           335                   0      14287
# 4        9523             12           254                   1       3645
#
#    Acima de 10 milhões  qtd_tipo_documento_CNPJ  qtd_tipo_documento_CPF  \
# 0                    2                     7054                   14996
# 1                    0                     8191                   23064
# 2                    0                     9215                   48074
# 3                    0                     4948                   33996
# 4                    0                     2872                   14476
#
#    valor_tipo_documento_CNPJ  valor_tipo_documento_CPF  \
# 0                  937817661                 512696666
# 1                  387614691                 345327362
# 2                  120788090                 145657243
# 3                   83440636                 151455640
# 4                   61650617                  99546993
#
#    min_valor_tipo_documento_CNPJ  min_valor_tipo_documento_CPF  \
# 0                            966                           430
# 1                            375                           378
# 2                            375                           375
# 3                            380                           400
# 4                            387                           400
#
#    mediana_valor_tipo_documento_CNPJ  mediana_valor_tipo_documento_CPF  \
# 0                             100000                             23110
# 1                              25000                             10000
# 2                               6720                              2000
# 3                              10000                              3000
# 4                              15000                              5000
#
#    max_valor_tipo_documento_CNPJ  max_valor_tipo_documento_CPF  \
# 0                       22109765                        735000
# 1                       15333334                        640000
# 2                         437000                        158500
# 3                         345122                        322559
# 4                         622056                        150000
#
#    media_valor_tipo_documento_CNPJ  media_valor_tipo_documento_CPF  \
# 0                           284619                           35471
# 1                            64133                           15262
# 2                            13595                            3143
# 3                            18152                            4630
# 4                            24253                            7068
#
#    qtd_sexo_Feminino  qtd_sexo_Masculino  valor_sexo_Feminino  \
# 0               7101                7891            251685116
# 1              10740               12321            157622640
# 2              23582               24492             63164177
# 3              15320               18672             63417567
# 4               6200                8274             42306319
#
#    valor_sexo_Masculino  total_qtd_sexo_valido  total_valor_sexo_valido  \
# 0             260854654                  14992                512539770
# 1             187634472                  23061                345257112
# 2              82493067                  48074                145657243
# 3              88023204                  33992                151440771
# 4              57222027                  14474                 99528345
#
#    percentual_valor_urbano_por_porte  percentual_valor_rural_por_porte  \
# 0                               0.94                              0.06
# 1                               0.96                              0.02
# 2                               0.85                              0.15
# 3                               0.87                              0.12
# 4                               0.92                              0.08
#
#    percentual_valor_por_porte  percentual_quantidade_por_porte  \
# 0                        0.51                             0.13
# 1                        0.26                             0.19
# 2                        0.09                             0.34
# 3                        0.08                             0.23
# 4                        0.06                             0.10
#
#    percentual_qtd_sexo_Feminino  percentual_qtd_sexo_Masculino  \
# 0                          0.47                           0.53
# 1                          0.47                           0.53
# 2                          0.49                           0.51
# 3                          0.45                           0.55
# 4                          0.43                           0.57
#
#    percentual_valor_sexo_Feminino  percentual_valor_sexo_Masculino
# 0                            0.49                             0.51
# 1                            0.46                             0.54
# 2                            0.43                             0.57
# 3                            0.42                             0.58
# 4                            0.43                             0.57

# %%
df_executed_by_state =
