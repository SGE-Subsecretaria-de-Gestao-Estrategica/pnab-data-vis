# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parents[1]

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.config import settings
# from src.aggregations import , person, labor,cadunico
import pandas as pd 
import numpy as np
from pathlib import Path

# import importlib
# importlib.reload(settings)
# importlib.reload(territorial)
# importlib.reload(person)
# importlib.reload(labor)
# importlib.reload(cadunico)

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", "{:,.2f}".format)

# %%
df_big_number = pd.read_csv(settings.DATA_PATH_SECTION1 / 'bignumber1.csv')

# %%
df_executed_by_uf = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_uf.csv')

# %%
df_executed_by_state = pd.read_csv(settings.DATA_PATH_SECTION1 / 'executed_value_by_state.csv')

# %%
df_executed_by_pop_size = pd.read_csv(settings.DATA_PATH_SECTION1 / 'values_by_population_size.csv')

# %%
df_executed_by_pop_size[['porte_populacional', 'valor_total_por_porte', 'valor_urbano_por_porte', 'valor_rural_por_porte', 'percentual_valor_urbano_por_porte', 'percentual_valor_rural_por_porte']]
# Out:
#   porte_populacional  valor_total_por_porte  valor_urbano_por_porte  \
# 0                -99             1450514327              1364352208
# 1           4_grande              732942052               706336743
# 2        1_pequeno_i              266445333               226313099
# 3       2_pequeno_ii              234896276               204820060
# 4            3_medio              161197609               147500753
#
#    valor_rural_por_porte  percentual_valor_urbano_por_porte  \
# 0               81220798                               0.94
# 1               13439537                               0.96
# 2               39514921                               0.85
# 3               29163319                               0.87
# 4               12718074                               0.92
#
#    percentual_valor_rural_por_porte
# 0                              0.06
# 1                              0.02
# 2                              0.15
# 3                              0.12
# 4                              0.08

# %%
13439537 + 706336743
# Out:
# 719776280

# %%
df_executed_by_state =
